# %% [markdown]
# ## v5

# %%
import os
import numpy as np

fnames = []

download_dir = f'../data/all_{idx}_idx/'
if not os.path.exists(download_dir):
    os.mkdir(download_dir)
    
for i in range(len(alldt)):
    vital = alldt.getitem(i)[0]
    fname = alldt.jf[i]['pt_id_date']
    fnames.append(fname)
    
    np.save(os.path.join(download_dir,f'{fname}.npy'),vital)

# %%
np.load(os.path.join(download_dir,f'{fnames[0]}.npy'))
# Out:
# array([[[1.84362709e+00, 1.84361830e+00, 4.08437107e+00, ...,
#          7.16978993e-08, 1.45415599e-02, 7.63188332e-01],
#         [6.67586368e+01, 1.21403556e+02, 1.36486429e+02, ...,
#          2.51305497e+02, 2.07329691e+00, 3.11006084e+01],
#         [3.02352816e+01, 1.23383554e+01, 1.62621192e+01, ...,
#          6.71505329e+01, 1.90221214e+00, 3.11314277e+01],
#         ...,
#         [4.01032060e-07, 3.82640370e-07, 3.44607394e-07, ...,
#          3.45250921e-07, 3.80914059e-07, 4.04005710e-07],
#         [5.17996689e-07, 4.63731015e-07, 4.82586762e-07, ...,
#          4.58527565e-07, 4.97482038e-07, 5.29671052e-07],
#         [1.35632237e-05, 1.31210793e-05, 1.15738607e-05, ...,
#          1.16363854e-05, 1.29396129e-05, 1.36921417e-05]],
#
#        [[2.52418345e-05, 9.35103652e-06, 1.97629905e-05, ...,
#          1.91603035e-05, 3.03112137e-06, 8.44765120e-05],
#         [4.13431423e-03, 1.33243557e-03, 4.47310979e-03, ...,
# ...
